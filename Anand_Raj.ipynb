# %%
import pandas as pd

listings = pd.read_csv("https://storage.googleapis.com/public-data-337819/listings%202%20reduced.csv",low_memory=False)
reviews = pd.read_csv("https://storage.googleapis.com/public-data-337819/reviews%202%20reduced.csv",low_memory=False)

# %%
print(listings.head().to_markdown())
print(reviews.head().to_markdown())
# Out:
# |    |    id | listing_url                        |      scrape_id | last_scraped   | source      | name                                                                      | description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           
# ...

# %%
print(listings.head())
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  92644  https://www.airbnb.com/rooms/92644  20230906022807   2023-09-06
# 1  93015  https://www.airbnb.com/rooms/93015  20230906022807   2023-09-06
# 2  13913  https://www.airbnb.com/rooms/13913  20230906022807   2023-09-06
# 3  15400  https://www.airbnb.com/rooms/15400  20230906022807   2023-09-06
# 4  93734  https://www.airbnb.com/rooms/93734  20230906022807   2023-09-07
#
#         source                                               name  \
# 0  city scrape  Rental unit in Earlsfield · ★4.57 · 1 bedroom ...
# 1  city scrape  Rental unit in Hammersmith · ★4.82 · 2 bedroom...
# 2  city scrape  Rental unit in Islington · ★4.80 · 1 bedroom ·...
# 3  city scrape  Rental unit in London · ★4.80 · 1 bedroom · 1 ...
# 4  city scrape  Condo in London · ★4.62 · 1 bedroom · 1 bed · ...
#
#                                          description  \
# 0  <b>The space</b><br />Hi everyone! I have 2 ro...
# ...

# %% [markdown]
# What is the neighborhood in which superhosts have the biggest median price difference with respect to non superhosts? Use the following three columns in the 'listings' dataset to answer this question: 'host_is_superhost', 'neighbourhood_cleansed', and 'price'.

# %%
# listings['price'] = listings['price'].replace({'\$': '', ',': ''}, regex=True).astype(float)
# superhost_median = listings[listings['host_is_superhost'] == 't'].groupby('neighbourhood_cleansed')['price'].median()
# non_superhost_median = listings[listings['host_is_superhost'] == 'f'].groupby('neighbourhood_cleansed')['price'].median()

# # Find the difference in median prices between superhosts and non-superhosts
# price_difference = superhost_median - non_superhost_median

# # Identify the neighborhood with the largest price difference
# largest_diff_neighborhood = price_difference.idxmax()
# largest_diff_value = price_difference.max()
# print(largest_diff_neighborhood )

# %%
listings['price']=listings['price'].replace({'\$':'', ',': ''},regex=True).astype(float)

# %%
listings['price']
# Out:
# 0         42.0
# 1        175.0
# 2         79.0
# 3        150.0
# 4         46.0
#          ...
# 87941    275.0
# 87942    145.0
# 87943    160.0
# 87944    680.0
# 87945    170.0
# Name: price, Length: 87946, dtype: float64

# %%
df1=listings[listings['host_is_superhost'] == 't'].groupby('neighbourhood_cleansed')['price'].median()
df1
# Out:
# neighbourhood_cleansed
# Barking and Dagenham       63.5
# Barnet                    112.0
# Bexley                     50.0
# Brent                      85.0
# Bromley                    64.5
# Camden                    153.0
# City of London            170.0
# Croydon                    55.0
# Ealing                     80.0
# Enfield                    65.0
# Greenwich                  90.0
# Hackney                   120.0
# Hammersmith and Fulham    131.0
# Haringey                   85.0
# Harrow                     70.0
# Havering                   50.5
# Hillingdon                 69.0
# Hounslow                   76.0
# Islington                 136.5
# Kensington and Chelsea    231.5
# Kingston upon Thames       80.0
# Lambeth                   100.0
# Lewisham                   76.0
# Merton                     76.5
# Newham                     82.0
# Redbridge                  73.0
# Richmond upon Thames      101.0
# Southwark                 123.5
# ...

# %%
df2=listings[listings['host_is_superhost'] == 'f'].groupby('neighbourhood_cleansed')['price'].median()
df2
# Out:
# neighbourhood_cleansed
# Barking and Dagenham       75.0
# Barnet                     89.0
# Bexley                     70.0
# Brent                      91.0
# Bromley                    79.0
# Camden                    131.0
# City of London            170.0
# Croydon                    75.0
# Ealing                     86.0
# Enfield                    80.0
# Greenwich                  90.0
# Hackney                    95.0
# Hammersmith and Fulham    125.0
# Haringey                   80.0
# Harrow                     78.5
# Havering                   89.0
# Hillingdon                 72.5
# Hounslow                  100.0
# Islington                 102.0
# Kensington and Chelsea    187.0
# Kingston upon Thames       86.0
# Lambeth                    95.0
# Lewisham                   80.0
# Merton                    100.0
# Newham                     86.0
# Redbridge                  70.0
# Richmond upon Thames      120.0
# Southwark                 100.0
# ...

# %%
df1-df2
# Out:
# neighbourhood_cleansed
# Barking and Dagenham     -11.5
# Barnet                    23.0
# Bexley                   -20.0
# Brent                     -6.0
# Bromley                  -14.5
# Camden                    22.0
# City of London             0.0
# Croydon                  -20.0
# Ealing                    -6.0
# Enfield                  -15.0
# Greenwich                  0.0
# Hackney                   25.0
# Hammersmith and Fulham     6.0
# Haringey                   5.0
# Harrow                    -8.5
# Havering                 -38.5
# Hillingdon                -3.5
# Hounslow                 -24.0
# Islington                 34.5
# Kensington and Chelsea    44.5
# Kingston upon Thames      -6.0
# Lambeth                    5.0
# Lewisham                  -4.0
# Merton                   -23.5
# Newham                    -4.0
# Redbridge                  3.0
# Richmond upon Thames     -19.0
# Southwark                 23.5
# Sutton                   -24.5
# ...

# %%
(df1-df2).idxmax()
# Out:
# 'Westminster'
